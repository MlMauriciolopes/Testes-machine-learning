# %% [markdown]
# <a href="https://colab.research.google.com/github/MlMauriciolopes/Testes-machine-learning/blob/main/yfinace_obter_dados_investidores_institucionais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Descobrindo os investidores institucioanais de um papel utilizando Python

# %%
#!pip install yfinance

# %%
import yfinance as yf

# %%
# Passa um papel de seu interesse
# "petro" será a referência para vários atributos que podemos utilizar para obter informações como:
# Acionistas, balanços dividendos, etc, no caso acionistas institucionais.
petro = yf.Ticker("PETR4.SA")

# %%
# Obter uma visão macro da divisão
petro.major_holders
# Out:
#         0                                      1
# 0  16.09%        % of Shares Held by All Insider
# 1  41.82%       % of Shares Held by Institutions
# 2  49.83%        % of Float Held by Institutions
# 3     486  Number of Institutions Holding Shares

# %%
# Obter visualizar no detalhe os "Top Mutual Fund Holders"
petro.institutional_holders
# Out:
#                                               Holder  ...       Value
# 0                            Europacific Growth Fund  ...  3910891213
# 1  Vanguard International Stock Index-Total Intl ...  ...  1990428835
# 2  Goldman Sachs GQG Partners International Oppor...  ...  1914847662
# 3                            iShares MSCI Brazil ETF  ...  1982250792
# 4  Vanguard International Stock Index-Emerging Ma...  ...  1490208487
# 5             iShares Core MSCI Emerging Markets ETF  ...  1222614433
# 6  Advisors Inner Circle Fund III-GQG Partners Em...  ...   610314594
# 7         DFA Emerging Markets Core Equity Portfolio  ...   599533299
# 8                  iShares MSCI Emerging Markets ETF  ...   521144527
# 9  Schwab Strategic Tr-Schwab Fundamental Emg Mkt...  ...   385142405
#
# [10 rows x 5 columns]
